# %% [markdown]
# #  Como importa el modelo desde colab

# %% [markdown]
# El modelo fue entrenado con scikit-learn 1.8.0, pero tiene de base scikit-learn 1.4.2, por lo que se debe actualizar antes de poder cargar el modelo, esto se hace de la siguiente manera:

# %%
# !pip uninstall -y scikit-learn
# !pip install scikit-learn==1.8.0 joblib numpy
# Out:
# Found existing installation: scikit-learn 1.4.2
# Uninstalling scikit-learn-1.4.2:
#   Successfully uninstalled scikit-learn-1.4.2
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 63.6 MB/s eta 0:00:00

# %% [markdown]
# Una vez actualizado debe recargar la pag, para que la actualizacion funcione, esto con ctrl + r, o con en icono para recargar que se encuentra en la esquina superior izquierda a la par de la casita en el buscador

# %% [markdown]
# Una vez actualizado ya puede subir el modelo a colab, puede usar el siguiente comando para verificar si el modelo se subio correctamente

# %%
# !ls -lh /content/modelo_FlightOnTime.pkl
# Out:
# -rw-r--r-- 1 root root 268K Jan 10 02:02 /content/modelo_FlightOnTime.pkl

# %% [markdown]
# Una vez hecho esto ya puede importa el modelo de la siguiente forma:

# %%
import joblib

modelo = joblib.load("/content/modelo_FlightOnTime.pkl")

# %% [markdown]
# Puedes confirmar que el modelo existe y es el esperado asi:

# %%
type(modelo)
# Out:
# sklearn.pipeline.Pipeline

# %% [markdown]
# O tener una vista previa del modelo:

# %%
print(modelo)
# Out:
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('model',
#                  GradientBoostingClassifier(learning_rate=0.05,
#                                             n_estimators=200,
#                                             random_state=42))])

# %%
for k, v in modelo.get_params().items():
    print(f"{k}: {v}")
# Out:
# memory: None
# steps: [('scaler', StandardScaler()), ('model', GradientBoostingClassifier(learning_rate=0.05, n_estimators=200,
#                            random_state=42))]
# transform_input: None
# verbose: False
# scaler: StandardScaler()
# model: GradientBoostingClassifier(learning_rate=0.05, n_estimators=200,
#                            random_state=42)
# scaler__copy: True
# scaler__with_mean: True
# scaler__with_std: True
# model__ccp_alpha: 0.0
# model__criterion: friedman_mse
# model__init: None
# model__learning_rate: 0.05
# model__loss: log_loss
# model__max_depth: 3
# model__max_features: None
# model__max_leaf_nodes: None
# model__min_impurity_decrease: 0.0
# model__min_samples_leaf: 1
# model__min_samples_split: 2
# model__min_weight_fraction_leaf: 0.0
# model__n_estimators: 200
# model__n_iter_no_change: None
# model__random_state: 42
# model__subsample: 1.0
# model__tol: 0.0001
# model__validation_fraction: 0.1
# model__verbose: 0
# model__warm_start: False

# %% [markdown]
# Y listo el modelo esta listo para poder hacer las verificaciones procedientes.
